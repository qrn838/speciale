# %% [markdown]
# # Life Cycle Labor Supply

# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np

import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Consumption-Saving Model

# %%
# load local model file and initialize model class
from DynLaborSickModel import *
# model = UIEmploymentModelClass()
model = FullLaborModelClass()

par = model.par
sol = model.sol
sim = model.sim

model.setup()
model.allocate()

# Disable the full rejection mechanism (utility penalty + EV weighting)
par.E_p_doc_out[:] = 0.0
par.p_doc_out[:] = 0.0

# %%
model.solve()

# %%
model.simulate()

# %%
hz_ue = model.hazard_u_to_e(t0=0)
hz_us = model.hazard_u_to_s(t0=0)
hz_s  = model.hazard_s_pooled()

fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# ── U → E ─────────────────────────────────────────────────────────────────
ax = axes[0, 0]
ax.plot(hz_ue["duration"], hz_ue["hazard"], color="darkseagreen")
ax.set_xlabel("Unemployment duration")
ax.set_ylabel("Hazard")
ax.set_title("U → E")
ax.grid(True)

# ── U → S ─────────────────────────────────────────────────────────────────
ax = axes[0, 1]
ax.plot(hz_us["duration"], hz_us["hazard"], color="darkred")
ax.set_xlabel("Unemployment duration")
ax.set_ylabel("Hazard")
ax.set_title("U → S")
ax.grid(True)

# ── S → E ─────────────────────────────────────────────────────────────────
ax = axes[1, 0]
ax.plot(hz_s["duration"], hz_s["hazard_E"],       color="tan",       label="Pooled")
ax.plot(hz_s["duration"], hz_s["hazard_E_Eorig"], color="sienna",    label="E-origin", linestyle="--")
ax.plot(hz_s["duration"], np.zeros(len(hz_s)),      color="steelblue", label="U-origin", linestyle=":")
ax.axvline(model.par.t_reassess, color="gray", linestyle="--", alpha=0.6,
           label=f"Reassessment (d={model.par.t_reassess})")
ax.set_xlabel("Sick leave duration")
ax.set_ylabel("Hazard")
ax.set_title("S → E")
ax.legend()
ax.grid(True)

# ── S → U ─────────────────────────────────────────────────────────────────
ax = axes[1, 1]
ax.plot(hz_s["duration"], hz_s["hazard_U"],       color="lightblue", label="Pooled")
ax.plot(hz_s["duration"], hz_s["hazard_U_Eorig"], color="sienna",    label="E-origin", linestyle="--")
ax.plot(hz_s["duration"], hz_s["hazard_U_Uorig"], color="steelblue", label="U-origin", linestyle=":")
ax.axvline(model.par.t_reassess, color="gray", linestyle="--", alpha=0.6,
           label=f"Reassessment (d={model.par.t_reassess})")
ax.set_xlabel("Sick leave duration")
ax.set_ylabel("Hazard")
ax.set_title("S → U")
ax.legend()
ax.grid(True)

plt.tight_layout()
plt.show()
